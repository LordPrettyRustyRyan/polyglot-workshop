# %%
var1 = 'yo wassup yall'

# %%
var1 = var1[:11] + 'bitches'

# %%
print (var1)
# Out:
# yo wassup ybitches

# %%
x = [1,2,3]
y = [1,2,3]
result = x is y
print(result)
# Out:
# False

# %%
tuple1 = (1,2,3)
tuple2 = (4,5,6)
result = tuple1 * 2 + tuple2
print(result)
# Out:
# (1, 2, 3, 1, 2, 3, 4, 5, 6)

# %%
a = 10
b = 3
c = a/b
print(c)
# Out:
# 3.3333333333333335

# %%
(5+3) * (10-2) / 4
# Out:
# 16.0

# %%
for i in range (3):
  for j in range (2): print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
my_dick = {'a':1, 'b':2, 'c':3}
print (my_dick['b'])
# Out:
# 2

# %%
from random import randint, seed
seed (42)
random_numbers = [randint(1, 100) for _ in range(5)]
print (random_numbers)
# Out:
# [82, 15, 4, 95, 36]

# %%
dick = "hello, world!"
print (dick[-2::-2])
# Out:
# drw,le

# %%
import numpy as np
array = np.array([1,10,2])
print(array)
# Out:
# [ 1 10  2]

# %%
def mystery_func (a, b=2, *args, **kwargs):
  return a +b * len(args) - kwargs.get ('c', 0)
result = mystery_func (1, 2, 3, 4, c=5)
print(result)
# Out:
# 0

# %%
import pandas as pd

# %%
mf = pd.read_cbz(r'"C:\Users\imagine\Downloads\Chapter.cbz"')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-906281c5a671> in <cell line: 1>()
# ----> 1 mf = pd.read_cbz(r'"C:\Users\imagine\Downloads\Chapter.cbz"')
#
# AttributeError: module 'pandas' has no attribute 'read_cbz'

# %%
n = "nigga"
print ("bitch", n)
# Out:
# bitch nigga

# %%
a, b = "2", 3
c = "@"
print ((a+c) *b)
# Out:
# 2@2@2@

# %%
n = input("n means :")
print (n)
# Out:
# n means :nigga
# nigga

# %%
str = "nigga get  yo ass up"
print(len(str))
print(str[-5:-1])
# Out:
# 20
# ss u

# %%
marks = 72
if (90>marks>70):
  print("yes")
else:
  print("no")
# Out:
# yes

# %%
t = int(input("fg"))
print(2*t)
# Out:
# fg5
# 10

# %%
def cum(n):#54321

  print(n)

  if(n==0):
    return
  cum(n-1)

cum(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 0

# %%
x = int(input("Enter a number: ")) # The user enters 2
print(x * "5")
# Out:
# Enter a number: 5
# 55555

# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5

# %%
x = 10

if x == 10:
    print(x == 10)
if x > 5:
    print(x > 5)
if x < 10:
    print(x < 10)
else:
    print("else")
# Out:
# True
# True
# else

# %%
n = 0

while n != 3:
    print(n)
    n += 1
else:
    print(n, "else")

print()

for i in range(0, 3):
    print(i)
else:
    print(i, "else")
# Out:
# 0
# 1
# 2
# 3 else
#
# 0
# 1
# 2
# 2 else

# %%
z = 10
y = 0
x = y < z and z > y or y > z and z < y

# %%
def f(x):
    if x == 0:
        return 0
    return x + f(x - 1)


print(f(3))
# Out:
# 6

# %%
def fun(x):
    x += 1
    return x


x = 2
x = fun(x + 1)
print(x)
# Out:
# 4

# %%
def func_1(a):
    return a ** a


def func_2(a):
    return func_1(a) * func_1(a)


print(func_2(2))
# Out:
# 16

# %%
def func(a, b):
    return a ** a


print(func(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-543f010b631a> in <cell line: 0>()
#       3
#       4
# ----> 5 print(func(2))
#
# TypeError: func() missing 1 required positional argument: 'b'

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return


print(fun(fun(2)) + 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2de3ac5321cc> in <cell line: 0>()
#       6
#       7
# ----> 8 print(fun(fun(2)) + 1)
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %%
def fun(x):
    global y
    y = x * x
    return y


fun(2)
print(y)
# Out:
# 4

# %%
def any():
    print(var + 1, end='')


var = 1
any()
print(var)
# Out:
# 21

# %%
my_list = ['Mary', 'had', 'a', 'little', 'lamb']


def my_list(my_list):
    del my_list[3]
    my_list[3] = 'ram'


print(my_list(my_list))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-34e61382032d> in <cell line: 0>()
#       7
#       8
# ----> 9 print(my_list(my_list))
#
# <ipython-input-9-34e61382032d> in my_list(my_list)
#       3
#       4 def my_list(my_list):
# ----> 5     del my_list[3]
#       6     my_list[3] = 'ram'
#       7
#
# TypeError: 'function' object does not support item deletion

# %%
def fun(x, y, z):
    return x + 2 * y + 3 * z


print(fun(0, z=1, y=3))
# Out:
# 9

# %%
def fun(inp=2, out=3):
    return inp * out


print(fun(out=2))
# Out:
# 4

# %%
dictionary = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dictionary['one']

for k in range(len(dictionary)):
    v = dictionary[v]

print(v)
# Out:
# two

# %%
tup = (1, 2, 4, 8)
tup = tup[1:-1]
tup = tup[0]
print(tup)
# Out:
# 2

# %%
try:
    value = input("Enter a value: ")
    print(value/value)
except ValueError:
    print("Bad input...")
except ZeroDivisionError:
    print("Very bad input...")
except TypeError:
    print("Very very bad input...")
except:
    print("Booo!")
# Out:
# Enter a value: sf
# Very very bad input...

# %%
my_list = [1, 2]

for v in range(2):
    my_list.insert(-1, my_list[v])

print(my_list)
# Out:
# [1, 1, 1, 2]

# %%
def function_1(a):
    return None


def function_2(a):
    return function_1(a) * function_1(a)


print(function_2(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-b5ea012c8eb0> in <cell line: 0>()
#       7
#       8
# ----> 9 print(function_2(2))
#
# <ipython-input-16-b5ea012c8eb0> in function_2(a)
#       4
#       5 def function_2(a):
# ----> 6     return function_1(a) * function_1(a)
#       7
#       8
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %%
def func(a, b):
    return b ** a


print(func(b=2, 2))
# Out:
#   File "<ipython-input-18-968707335caa>", line 5
#     print(func(b=2, 2))
#                      ^
# SyntaxError: positional argument follows keyword argument

# %%
my_list = [x * x for x in range(5)]


def fun(lst):
    del lst[lst[2]]
    return lst


print(fun(my_list))
# Out:
# [0, 1, 4, 9]

# %%
x = 1
y = 2
x, y, z = x, x, y
z, y, z = x, y, z

print(x, y, z)
# Out:
# 1 1 2

# %%
tup = (1, 2, 4, 8)
tup = tup[-2:-1]
tup = tup[-1]
print(tup)
# Out:
# 4

# %%
dct = {'one': 'two', 'three': 'one', 'two': 'three'}
v = dct['three']

for k in range(len(dct)):
    v = dct[v]

print(v)
# Out:
# one

# %%
x = float(input())
y = float(input())
print(y ** (1 / x))
# Out:
# 2
# 4
# 2.0

# %%
dd = {"1": "0", "0": "1"}
for x in dd.vals():
    print(x, end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-488ad3b16617> in <cell line: 0>()
#       1 dd = {"1": "0", "0": "1"}
# ----> 2 for x in dd.vals():
#       3     print(x, end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %%
dct = {}
dct['1'] = (1, 2)
dct['2'] = (2, 1)

for x in dct.keys():
    print(dct[x][1], end="")
# Out:
# 21

# %%
def fun(inp=2, out=3):
    return inp * out


print(fun(out=2))
# Out:
# 4

# %%
lst = [[x for x in range(3)] for y in range(3)]

for r in range(3):
    for c in range(3):
        if lst[r][c] % 2 != 0:
            print("#")
# Out:
# #
# #
# #

# %%
try:
    value = input("Enter a value: ")
    print(int(value)/len(value))
except ValueError:
    print("Bad input...")
except ZeroDivisionError:
    print("Very bad input...")
except TypeError:
    print("Very very bad input...")
except:
    print("Booo!")
# Out:
# Enter a value: 0
# 0.0
